# %% [markdown]
# Step1. Import Module
#
# Step2. Check Device
#
# Step3. Download CIFAR10 Data
#
# Step4. Check Data
#
# Step5. Check Data
#
# Step6. MLP Model
#
# Step7. Optimizer, Objective Function
#
# Step8. Check Train data's Loss
#
# Step8. Check Vaild data's Loss
#
# Step9. Check Test set Accuracy

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn               #pytorch module 중 인공신경망 설계할때 필요한 함수
import torch.nn.functional as F     #nn중에서도 자주 이용되는 함수 F
from torchvision import transforms, datasets

# %%
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else : 
    DEVICE = torch.device('cpu')
    
print('Using Pytorch version : ', torch.__version__, 'Device :', DEVICE)
# Out:
# Using Pytorch version :  1.9.1 Device : cpu

# %%
BATCH_SIZE = 32                      #Iteration = 전체데이터개수 / batch_size , back propagation을 진행하는 단위
EPOCHS = 10                          #Epochs는 존재하고 있는 Mini_batch를 전부 이용하는 횟수를 의미

# %%
train_dataset = datasets.CIFAR10(root = "../data/CIFAR_10",
                                 train = True,
                                 download = True,                   #인터넷에서 다운로드
                                 transform = transforms.ToTensor()) #transforms으로 0~255, -> 0~1로 정규화
test_dataset = datasets.CIFAR10(root = "../data/CIFAR_10",
                                 train = False,
                                 transform = transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = BATCH_SIZE,
                                           shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)
# Out:
# Files already downloaded and verified

# %%
for (X_train, y_train) in train_loader:
    print('X_train :', X_train.size(),'type : ', X_train.type())
    print('y_train :', y_train.size(),'type :', y_train.type())
    break
# Out:
# X_train : torch.Size([32, 3, 32, 32]) type :  torch.FloatTensor
# y_train : torch.Size([32]) type : torch.LongTensor

# %%
pltsize = 2
plt.figure(figsize=(10*pltsize, 3*pltsize))

for i in range(32):
    plt.subplot(4, 8, i+1)
    plt.axis('off')
    plt.imshow(np.transpose(X_train[i],(1,2,0))) #X_train[i]([channel],[height],[width]) --> X_train[i]([width],[height],[channel])
    plt.title('Class:'+ str(y_train[i].item()))

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(32*32*3, 512) #(3072,512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10) #10가지 class 원-핫 인코딩 
    
    def forward(self, x):
        x = x.view(-1, 32 * 32 * 3) # 2차원데이터를 1차원으로 flatten 
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        x = F.relu(x)
        x = self.fc3(x)
        x = F.log_softmax(x, dim = 1)
        return x

# %%
model = Net().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr= 0.001)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=3072, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
#학습데이터에 대한 모델 성능
def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad() #zero로 초기화
        output = model(image)
        loss = criterion(output, label) #cross entropy로 loss값계산
        loss.backward() #계산된 loss값으로 back propagation을 통해 계산된 gradient값을 각 파라미터에 할당
        optimizer.step() #각 파라미터별로 할당된 gradient 값을 이용해 파라미터 값을 업데이트합니다
        
        if batch_idx % log_interval == 0 :
            print("Train Epochs : {} [{}/{}({:.0f}%)]|tTrain Loss: {:.6f}".format(
                Epoch, batch_idx*len(image),
                len(train_loader.dataset), 100.*batch_idx / len(train_loader),
                loss.item()))

# %%
#검증데이터에 대한 모델 성능
def evaluate(model, test_loader):
    model.eval()            #model을 평가상태로 바꾸기
    test_loss = 0       
    correct = 0
    with torch.no_grad():  #평가단계에 gradient 학습방지
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]   #제일큰확률찾기
            correct += prediction.eq(label.view_as(prediction)).sum().item() #올바르게 예측한 수 세기
    test_loss /= len(test_loader.dataset)  #test_loss(평균loss) = 지금까지계산된loss/minibatch개수
    test_accuracy = 100. * correct / len(test_loader.dataset) # 100* (올바르게 예측한 개수/minibatch개수)
    return test_loss, test_accuracy

# %%
for Epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("/n[EPOCH:{}], /tTest Loss : {:.4f}, /tTest Accuracy: {:.2f} % /n".
         format(Epoch, test_loss, test_accuracy))
# Out:
# Train Epochs : 1 [0/50000(0%)]|tTrain Loss: 2.296944
# Train Epochs : 1 [6400/50000(13%)]|tTrain Loss: 1.948878
# Train Epochs : 1 [12800/50000(26%)]|tTrain Loss: 2.123058
# Train Epochs : 1 [19200/50000(38%)]|tTrain Loss: 1.997883
# Train Epochs : 1 [25600/50000(51%)]|tTrain Loss: 2.016070
# Train Epochs : 1 [32000/50000(64%)]|tTrain Loss: 1.729563
# Train Epochs : 1 [38400/50000(77%)]|tTrain Loss: 2.020726
# Train Epochs : 1 [44800/50000(90%)]|tTrain Loss: 1.559327
# /n[EPOCH:1], /tTest Loss : 0.0526, /tTest Accuracy: 40.42 % /n
# Train Epochs : 2 [0/50000(0%)]|tTrain Loss: 1.599557
# Train Epochs : 2 [6400/50000(13%)]|tTrain Loss: 1.523241
# Train Epochs : 2 [12800/50000(26%)]|tTrain Loss: 1.681517
# Train Epochs : 2 [19200/50000(38%)]|tTrain Loss: 1.617804
# Train Epochs : 2 [25600/50000(51%)]|tTrain Loss: 1.799802
# Train Epochs : 2 [32000/50000(64%)]|tTrain Loss: 1.891501
# Train Epochs : 2 [38400/50000(77%)]|tTrain Loss: 1.416871
# Train Epochs : 2 [44800/50000(90%)]|tTrain Loss: 1.430840
# /n[EPOCH:2], /tTest Loss : 0.0508, /tTest Accuracy: 41.61 % /n
# Train Epochs : 3 [0/50000(0%)]|tTrain Loss: 1.293341
# Train Epochs : 3 [6400/50000(13%)]|tTrain Loss: 1.656750
# Train Epochs : 3 [12800/50000(26%)]|tTrain Loss: 1.896944
# Train Epochs : 3 [19200/50000(38%)]|tTrain Loss: 1.405733
# Train Epochs : 3 [25600/50000(51%)]|tTrain Loss: 1.413724
# Train Epochs : 3 [32000/50000(64%)]|tTrain Loss: 1.321261
# Train Epochs : 3 [38400/50000(77%)]|tTrain Loss: 1.908072
# Train Epochs : 3 [44800/50000(90%)]|tTrain Loss: 1.513397
# /n[EPOCH:3], /tTest Loss : 0.0490, /tTest Accuracy: 43.80 % /n
# Train Epochs : 4 [0/50000(0%)]|tTrain Loss: 1.680250
# Train Epochs : 4 [6400/50000(13%)]|tTrain Loss: 1.521919
# Train Epochs : 4 [12800/50000(26%)]|tTrain Loss: 1.296127
# Train Epochs : 4 [19200/50000(38%)]|tTrain Loss: 1.472263
# Train Epochs : 4 [25600/50000(51%)]|tTrain Loss: 1.369835
# Train Epochs : 4 [32000/50000(64%)]|tTrain Loss: 1.583467
# Train Epochs : 4 [38400/50000(77%)]|tTrain Loss: 1.752018
# Train Epochs : 4 [44800/50000(90%)]|tTrain Loss: 1.398784
# /n[EPOCH:4], /tTest Loss : 0.0474, /tTest Accuracy: 45.72 % /n
# Train Epochs : 5 [0/50000(0%)]|tTrain Loss: 1.488964
# Train Epochs : 5 [6400/50000(13%)]|tTrain Loss: 1.425181
# Train Epochs : 5 [12800/50000(26%)]|tTrain Loss: 1.449630
# Train Epochs : 5 [19200/50000(38%)]|tTrain Loss: 1.815735
# Train Epochs : 5 [25600/50000(51%)]|tTrain Loss: 2.073688
# Train Epochs : 5 [32000/50000(64%)]|tTrain Loss: 1.326108
# Train Epochs : 5 [38400/50000(77%)]|tTrain Loss: 1.500326
# Train Epochs : 5 [44800/50000(90%)]|tTrain Loss: 1.542579
# /n[EPOCH:5], /tTest Loss : 0.0479, /tTest Accuracy: 44.66 % /n
# Train Epochs : 6 [0/50000(0%)]|tTrain Loss: 1.428055
# Train Epochs : 6 [6400/50000(13%)]|tTrain Loss: 1.088932
# Train Epochs : 6 [12800/50000(26%)]|tTrain Loss: 1.485525
# Train Epochs : 6 [19200/50000(38%)]|tTrain Loss: 1.711793
# Train Epochs : 6 [25600/50000(51%)]|tTrain Loss: 1.407423
# Train Epochs : 6 [32000/50000(64%)]|tTrain Loss: 1.409368
# Train Epochs : 6 [38400/50000(77%)]|tTrain Loss: 1.610695
# Train Epochs : 6 [44800/50000(90%)]|tTrain Loss: 1.381001
# /n[EPOCH:6], /tTest Loss : 0.0466, /tTest Accuracy: 47.20 % /n
# Train Epochs : 7 [0/50000(0%)]|tTrain Loss: 1.427603
# Train Epochs : 7 [6400/50000(13%)]|tTrain Loss: 1.337677
# Train Epochs : 7 [12800/50000(26%)]|tTrain Loss: 1.657936
# Train Epochs : 7 [19200/50000(38%)]|tTrain Loss: 1.692257
# Train Epochs : 7 [25600/50000(51%)]|tTrain Loss: 1.459942
# Train Epochs : 7 [32000/50000(64%)]|tTrain Loss: 1.333414
# Train Epochs : 7 [38400/50000(77%)]|tTrain Loss: 1.645061
# Train Epochs : 7 [44800/50000(90%)]|tTrain Loss: 1.460190
# /n[EPOCH:7], /tTest Loss : 0.0470, /tTest Accuracy: 46.66 % /n
# Train Epochs : 8 [0/50000(0%)]|tTrain Loss: 1.223136
# Train Epochs : 8 [6400/50000(13%)]|tTrain Loss: 1.535694
# Train Epochs : 8 [12800/50000(26%)]|tTrain Loss: 1.253948
# Train Epochs : 8 [19200/50000(38%)]|tTrain Loss: 1.485161
# Train Epochs : 8 [25600/50000(51%)]|tTrain Loss: 1.409884
# Train Epochs : 8 [32000/50000(64%)]|tTrain Loss: 1.440797
# Train Epochs : 8 [38400/50000(77%)]|tTrain Loss: 1.343072
# Train Epochs : 8 [44800/50000(90%)]|tTrain Loss: 1.627959
# /n[EPOCH:8], /tTest Loss : 0.0460, /tTest Accuracy: 48.01 % /n
# Train Epochs : 9 [0/50000(0%)]|tTrain Loss: 1.274790
# Train Epochs : 9 [6400/50000(13%)]|tTrain Loss: 1.312417
# Train Epochs : 9 [12800/50000(26%)]|tTrain Loss: 1.401300
# Train Epochs : 9 [19200/50000(38%)]|tTrain Loss: 1.357656
# Train Epochs : 9 [25600/50000(51%)]|tTrain Loss: 1.462757
# Train Epochs : 9 [32000/50000(64%)]|tTrain Loss: 1.526736
# Train Epochs : 9 [38400/50000(77%)]|tTrain Loss: 1.513932
# Train Epochs : 9 [44800/50000(90%)]|tTrain Loss: 1.627761
# /n[EPOCH:9], /tTest Loss : 0.0470, /tTest Accuracy: 46.90 % /n
# Train Epochs : 10 [0/50000(0%)]|tTrain Loss: 1.749012
# Train Epochs : 10 [6400/50000(13%)]|tTrain Loss: 1.561242
# Train Epochs : 10 [12800/50000(26%)]|tTrain Loss: 1.320734
# Train Epochs : 10 [19200/50000(38%)]|tTrain Loss: 1.237573
# Train Epochs : 10 [25600/50000(51%)]|tTrain Loss: 1.233206
# Train Epochs : 10 [32000/50000(64%)]|tTrain Loss: 1.555582
# Train Epochs : 10 [38400/50000(77%)]|tTrain Loss: 0.965704
# Train Epochs : 10 [44800/50000(90%)]|tTrain Loss: 1.282447
# /n[EPOCH:10], /tTest Loss : 0.0455, /tTest Accuracy: 48.26 % /n
